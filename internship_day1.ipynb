# %%
name="Deva"
age=19
cgpa=8.5
placed=True
print("student name:",name)
print(type(name))
print(type(age))
print(type(cgpa))
print(type(placed))
# Out:
# student name: Deva
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name=["Deva","Aarthi","Divya"]
name.append("Krish")
marks=[50,40,80]
print(name[2])
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# Divya
# 80
# 4
# 3

# %%
days=("Monday","Tuesday","Wednesday")
print(days[1])
# Out:
# Tuesday

# %%
import numpy as np
marks=np.array([80,40,30,89])
print(marks)
# Out:
# [80 40 30 89]

# %%
import numpy as np
a=np.array([10,20,30])
b=np.array([2,3,4])
c=np.array([5,6,7])
result=a*b*c
print("a=",a)
print("b=",b)
print("c=",c)
print("Multiplication=",result)
# Out:
# a= [10 20 30]
# b= [2 3 4]
# c= [5 6 7]
# Multiplication= [100 360 840]
